# %% [markdown]
# Importing Modules

# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns 
import matplotlib.ticker as mtick
# %matplotlib inline
from sklearn.metrics import accuracy_score
import pickle
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv('dataset/Churn_Modelling.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
num_rows, num_columns = df.shape
print(num_rows, num_columns)
# Out:
# 10000 14

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#Columns details
df.columns.values
# Out:
# array(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'], dtype=object)

# %%
# Types of data
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df['Exited'].value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
# Dropping 'RowNumber', 'CustomerId', 'Surname' columns as they are not much useful for training
df = df.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1)

# %%
#Checking unique values in each column
print(df['Exited'].unique())
print(df['Geography'].unique())
print(df['Gender'].unique())
print(df['Tenure'].unique())
print(df['NumOfProducts'].unique())
print(df['HasCrCard'].unique())
print(df['IsActiveMember'].unique())
# Out:
# [1 0]
# ['France' 'Spain' 'Germany']
# ['Female' 'Male']
# [ 2  1  8  7  4  6  3 10  5  9  0]
# [1 3 2 4]
# [1 0]
# [1 0]

# %%
# Pllotting to see any imbalance in the data
feature_to_analyze = 'Exited'
plt.figure(figsize=(2, 2))
sns.countplot(x=feature_to_analyze, data=df)
plt.xlabel(feature_to_analyze)
plt.ylabel("Count")
plt.title(f"Count Plot for {feature_to_analyze}")
plt.show()
print("There is imbalace in the dataset and it need to be solved.")
# Out:
# There is imbalace in the dataset and it need to be solved.

# %%
#Plots
sns.pairplot(df,diag_kind = "kde",kind = "scatter")
# Out:
# D:\Apps\Python\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
# One hot encoding
categorical_cols = ['Geography', 'Gender', 'Tenure', 'NumOfProducts']
df = pd.get_dummies(df, columns=categorical_cols, dtype=int)

# %%
# # Label encoding.
# # Since "Geograhy" and "Gender" are in Categorical values converting them to labels using label encoding.
# label_en = LabelEncoder()
# df[['Geography','Gender']] = df[['Geography','Gender']].apply(lambda x: label_en.fit_transform(x))

# %%
X = df.drop('Exited', axis=1)
y = df['Exited']

# %%
# Scaling the data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
sm = SMOTE()
X_res, y_res = sm.fit_resample(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.15)

# %%
clf = RandomForestClassifier()
clf.fit(X_train, y_train)

# Make predictions
y_pred = clf.predict(X_test)

# Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9053997488488907
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.90      0.91      1198
#            1       0.90      0.91      0.91      1191
#
#     accuracy                           0.91      2389
#    macro avg       0.91      0.91      0.91      2389
# weighted avg       0.91      0.91      0.91      2389

# %%
#Confusion Matrix
cn = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(4, 3))
sns.heatmap(cn, annot=True, cmap="Blues", fmt="g", cbar=False)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
